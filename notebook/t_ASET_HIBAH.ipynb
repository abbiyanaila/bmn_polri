# %%
import arrow
import pandas as pd
from datetime import datetime
import numpy as np

def convert_todate(df, column_name):
    data_series = []
    len_data = len(df[column_name])
    for idx in range(len_data):
        data = df[column_name].iloc[idx]
        try:
            at = arrow.get(data)
            date = at.date()
            data = date
        except: # jika NAN or NAT
            data = "0000-00-00"

        data_series.append(data)

    df[column_name] = data_series
    return df

# %%
df = pd.read_csv("../data/ASET_HIBAH.csv", sep='|', encoding='ISO-8859-1')
# Out:
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (28,30,31,32,33,34,35,36,37,38,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    KODE_KL               NAMA_KL  KODE_KPKNL        NAMA_KPKNL  \
# 0       60  KEPOLISIAN NEGARA RI        7104  KPKNL JAKARTA IV
# 1       60  KEPOLISIAN NEGARA RI        7104  KPKNL JAKARTA IV
# 2       60  KEPOLISIAN NEGARA RI        7104  KPKNL JAKARTA IV
# 3       60  KEPOLISIAN NEGARA RI        7104  KPKNL JAKARTA IV
# 4       60  KEPOLISIAN NEGARA RI        7104  KPKNL JAKARTA IV
#
#             KODE_SATKER   NAMA_SATKER       KODE_SUB_SATKER NAMA_SUB_SATKER  \
# 0  060018100642267000KP  DIV TI POLRI  060018100642267000KP    DIV TI POLRI
# 1  060018100642267000KP  DIV TI POLRI  060018100642267000KP    DIV TI POLRI
# 2  060018100642267000KP  DIV TI POLRI  060018100642267000KP    DIV TI POLRI
# 3  060018100642267000KP  DIV TI POLRI  060018100642267000KP    DIV TI POLRI
# 4  060018100642267000KP  DIV TI POLRI  060018100642267000KP    DIV TI POLRI
#
#           KELOMPOK            SUB_KELOMPOK  ...  NO_DANA TGL_DANA  \
# 0  ALAT KOMUNIKASI  ALAT KOMUNIKASI SOSIAL  ...      NaN      NaN
# 1  ALAT KOMUNIKASI  ALAT KOMUNIKASI SOSIAL  ...      NaN      NaN
# 2  ALAT KOMUNIKASI  ALAT KOMUNIKASI SOSIAL  ...      NaN      NaN
# 3  ALAT KOMUNIKASI  ALAT KOMUNIKASI SOSIAL  ...      NaN      NaN
# 4  ALAT KOMUNIKASI  ALAT KOMUNIKASI SOSIAL  ...      NaN      NaN
#
#                         DARI         ASL_PERLH            TGL_PERLH NO_PSP  \
# 0  107 (Reklasifikasi Masuk)  APBN-P T.A. 2016  2016-12-13 00:00:00    NaN
# 1  107 (Reklasifikasi Masuk)  APBN-P T.A. 2016  2016-12-13 00:00:00    NaN
# 2  107 (Reklasifikasi Masuk)  APBN-P T.A. 2016  2016-12-13 00:00:00    NaN
# 3  107 (Reklasifikasi Masuk)  APBN-P T.A. 2016  2016-12-13 00:00:00    NaN
# 4  107 (Reklasifikasi Masuk)  APBN-P T.A. 2016  2016-12-13 00:00:00    NaN
#
#    TGL_PSP  STATUS_PENGELOLAAN                    STATUS_PENGGUNAAN  TGL_TARIK
# 0      NaN                 NaN  Digunakan sendiri untuk operasional   20200226
# 1      NaN                 NaN  Digunakan sendiri untuk operasional   20200226
# 2      NaN                 NaN  Digunakan sendiri untuk operasional   20200226
# 3      NaN                 NaN  Digunakan sendiri untuk operasional   20200226
# 4      NaN                 NaN  Digunakan sendiri untuk operasional   20200226
#
# [5 rows x 47 columns]

# %%
len(df)
# Out:
# 6330440

# %%
df.columns
# Out:
# Index(['KODE_KL', 'NAMA_KL', 'KODE_KPKNL', 'NAMA_KPKNL', 'KODE_SATKER',
#        'NAMA_SATKER', 'KODE_SUB_SATKER', 'NAMA_SUB_SATKER', 'KELOMPOK',
#        'SUB_KELOMPOK', 'KODE_BARANG', 'NAMA_BARANG', 'NUP', 'TGL_BUKU',
#        'TGL_REKAM', 'TGL_REKAM_PERTAMA', 'TGL_MUTASI', 'NO_BUKTI',
#        'KETERANGAN', 'NILAI_PEROLEHAN_PERTAMA', 'NILAI_MUTASI',
#        'NILAI_PEROLEHAN', 'NILAI_PENYUSUTAN', 'NILAI_BUKU', 'KONDISI', 'MERK',
#        'KUANTITAS', 'KODE_PROVINSI', 'URAIAN_PROVINSI', 'KODE_KAB_KOTA',
#        'URAIAN_KAB_KOTA', 'KECAMATAN', 'KELURAHAN_DESA', 'KODE_POS', 'RT_RW',
#        'ALAMAT', 'ALAMAT_LAINNYA', 'NO_DANA', 'TGL_DANA', 'DARI', 'ASL_PERLH',
#        'TGL_PERLH', 'NO_PSP', 'TGL_PSP', 'STATUS_PENGELOLAAN',
#        'STATUS_PENGGUNAAN', 'TGL_TARIK'],
#       dtype='object')

# %%
cname = ['TGL_BUKU', 'TGL_REKAM', 'TGL_REKAM_PERTAMA', 'TGL_MUTASI', 'TGL_DANA', 'TGL_PERLH', 'TGL_PSP', 'TGL_TARIK']

# %%
len(cname)
# Out:
# 8

# %%
df[cname[0]]
# Out:
# 0          2016-12-13 00:00:00
# 1          2016-12-13 00:00:00
# 2          2016-12-13 00:00:00
# 3          2016-12-13 00:00:00
# 4          2016-12-13 00:00:00
#                   ...
# 6330435    2017-12-20 00:00:00
# 6330436    2017-12-20 00:00:00
# 6330437    2017-12-20 00:00:00
# 6330438    2017-12-20 00:00:00
# 6330439    2017-12-20 00:00:00
# Name: TGL_BUKU, Length: 6330440, dtype: object

# %%
df = convert_todate(df, column_name=cname[0])
df[cname[0]]
# Out:
# 0          2016-12-13
# 1          2016-12-13
# 2          2016-12-13
# 3          2016-12-13
# 4          2016-12-13
#               ...
# 6330435    2017-12-20
# 6330436    2017-12-20
# 6330437    2017-12-20
# 6330438    2017-12-20
# 6330439    2017-12-20
# Name: TGL_BUKU, Length: 6330440, dtype: object

# %%
df[cname[1]]
# Out:
# 0          2016-12-13 00:00:00
# 1          2016-12-13 00:00:00
# 2          2016-12-13 00:00:00
# 3          2016-12-13 00:00:00
# 4          2016-12-13 00:00:00
#                   ...
# 6330435    2017-12-20 00:00:00
# 6330436    2017-12-20 00:00:00
# 6330437    2017-12-20 00:00:00
# 6330438    2017-12-20 00:00:00
# 6330439    2017-12-20 00:00:00
# Name: TGL_REKAM, Length: 6330440, dtype: object

# %%
df = convert_todate(df, column_name=cname[1])
df[cname[1]]
# Out:
# 0          2016-12-13
# 1          2016-12-13
# 2          2016-12-13
# 3          2016-12-13
# 4          2016-12-13
#               ...
# 6330435    2017-12-20
# 6330436    2017-12-20
# 6330437    2017-12-20
# 6330438    2017-12-20
# 6330439    2017-12-20
# Name: TGL_REKAM, Length: 6330440, dtype: object

# %%
df[cname[2]]
# Out:
# 0          2016-12-13 00:00:00
# 1          2016-12-13 00:00:00
# 2          2016-12-13 00:00:00
# 3          2016-12-13 00:00:00
# 4          2016-12-13 00:00:00
#                   ...
# 6330435    2017-12-20 00:00:00
# 6330436    2017-12-20 00:00:00
# 6330437    2017-12-20 00:00:00
# 6330438    2017-12-20 00:00:00
# 6330439    2017-12-20 00:00:00
# Name: TGL_REKAM_PERTAMA, Length: 6330440, dtype: object

# %%
df = convert_todate(df, column_name=cname[2])
df[cname[2]]
# Out:
# 0          2016-12-13
# 1          2016-12-13
# 2          2016-12-13
# 3          2016-12-13
# 4          2016-12-13
#               ...
# 6330435    2017-12-20
# 6330436    2017-12-20
# 6330437    2017-12-20
# 6330438    2017-12-20
# 6330439    2017-12-20
# Name: TGL_REKAM_PERTAMA, Length: 6330440, dtype: object

# %%
df[cname[3]]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#            ..
# 6330435   NaN
# 6330436   NaN
# 6330437   NaN
# 6330438   NaN
# 6330439   NaN
# Name: TGL_MUTASI, Length: 6330440, dtype: float64

# %%
df = convert_todate(df, column_name=cname[3])
df[cname[3]]
# Out:
# 0          0000-00-00
# 1          0000-00-00
# 2          0000-00-00
# 3          0000-00-00
# 4          0000-00-00
#               ...
# 6330435    0000-00-00
# 6330436    0000-00-00
# 6330437    0000-00-00
# 6330438    0000-00-00
# 6330439    0000-00-00
# Name: TGL_MUTASI, Length: 6330440, dtype: object

# %%
df[cname[4]]
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 6330435    NaN
# 6330436    NaN
# 6330437    NaN
# 6330438    NaN
# 6330439    NaN
# Name: TGL_DANA, Length: 6330440, dtype: object

# %%
df = convert_todate(df, column_name=cname[4])
df[cname[4]]
# Out:
# 0          0000-00-00
# 1          0000-00-00
# 2          0000-00-00
# 3          0000-00-00
# 4          0000-00-00
#               ...
# 6330435    0000-00-00
# 6330436    0000-00-00
# 6330437    0000-00-00
# 6330438    0000-00-00
# 6330439    0000-00-00
# Name: TGL_DANA, Length: 6330440, dtype: object

# %%
df[cname[5]]
# Out:
# 0          2016-12-13 00:00:00
# 1          2016-12-13 00:00:00
# 2          2016-12-13 00:00:00
# 3          2016-12-13 00:00:00
# 4          2016-12-13 00:00:00
#                   ...
# 6330435    2017-12-20 00:00:00
# 6330436    2017-12-20 00:00:00
# 6330437    2017-12-20 00:00:00
# 6330438    2017-12-20 00:00:00
# 6330439    2017-12-20 00:00:00
# Name: TGL_PERLH, Length: 6330440, dtype: object

# %%
df = convert_todate(df, column_name=cname[5])
df[cname[5]]
# Out:
# 0          2016-12-13
# 1          2016-12-13
# 2          2016-12-13
# 3          2016-12-13
# 4          2016-12-13
#               ...
# 6330435    2017-12-20
# 6330436    2017-12-20
# 6330437    2017-12-20
# 6330438    2017-12-20
# 6330439    2017-12-20
# Name: TGL_PERLH, Length: 6330440, dtype: object

# %%
df[cname[6]]
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 6330435    NaN
# 6330436    NaN
# 6330437    NaN
# 6330438    NaN
# 6330439    NaN
# Name: TGL_PSP, Length: 6330440, dtype: object

# %%
df = convert_todate(df, column_name=cname[6])
df[cname[6]]
# Out:
# 0          0000-00-00
# 1          0000-00-00
# 2          0000-00-00
# 3          0000-00-00
# 4          0000-00-00
#               ...
# 6330435    0000-00-00
# 6330436    0000-00-00
# 6330437    0000-00-00
# 6330438    0000-00-00
# 6330439    0000-00-00
# Name: TGL_PSP, Length: 6330440, dtype: object

# %%
df[cname[7]]
# Out:
# 0          20200226
# 1          20200226
# 2          20200226
# 3          20200226
# 4          20200226
#              ...
# 6330435    20200226
# 6330436    20200226
# 6330437    20200226
# 6330438    20200226
# 6330439    20200226
# Name: TGL_TARIK, Length: 6330440, dtype: int64

# %%
data = df
column_name = 'TGL_TARIK'

len_data = len(df)
# len_data = 10
data_series = []
for idx in range(len_data):
    len_data = len(df[column_name])
    data = df[column_name].iloc[idx]
    data = str(data)
    
    year = data[0:4]
    month = data[4:6]
    day = data[6:8]
    str_date = f'{year}-{month}-{day}'
#     print(str_date)

    try:
        at = arrow.get(str_date)
        date = at.date()
    except:
        str_date = f'0000-00-00'
#         at = arrow.get(str_date)
#         date = at.date()
        date = str_date
#         print(date)
#     print(date)

    data_series.append(date)

df[column_name] = data_series
df[column_name]
# return df
# Out:
# 0          2020-02-26
# 1          2020-02-26
# 2          2020-02-26
# 3          2020-02-26
# 4          2020-02-26
#               ...
# 6330435    2020-02-26
# 6330436    2020-02-26
# 6330437    2020-02-26
# 6330438    2020-02-26
# 6330439    2020-02-26
# Name: TGL_TARIK, Length: 6330440, dtype: object

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql://root:191618@localhost/db_logpolri')

# %%
df.to_sql('t_ASET_HIBAH', con=engine, if_exists='append', chunksize=500, index=False)
# Out:
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 175
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 176
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 177
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 178
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 179
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 57
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 33
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 36
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 39
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 42
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 100
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 103
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 106
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 110
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 297
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 198
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 200
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 202
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 204
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 206
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 226
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 227
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 228
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 229
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 230
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 231
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 232
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 233
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 234
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 235
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 236
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 237
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 238
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 239
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 166
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 167
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 168
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 169
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 222
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 223
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 224
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 225
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 77
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 101
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 104
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 60
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 182
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 62
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 64
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 65
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 67
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 68
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 69
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 73
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 399
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 472
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 474
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 477
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 480
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 9
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 12
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 35
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 44
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 46
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 66
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 115
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 192
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 210
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 241
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 250
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 251
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 264
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 293
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 339
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 369
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 378
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 10
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 11
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 15
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 25
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 26
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 27
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 28
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 29
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 70
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 75
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 78
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 79
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 82
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 91
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 93
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 131
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 132
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 134
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 135
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 136
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 137
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 138
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 139
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 140
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 141
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 142
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 143
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 144
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 145
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 194
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 195
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 196
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 197
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 199
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 201
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 203
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 205
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 207
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 208
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 1
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 2
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 4
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 5
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 7
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 8
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 16
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 17
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 19
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 22
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 24
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 30
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 38
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 40
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 41
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 47
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 50
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 51
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 55
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 419
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 490
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 109
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 180
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 183
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 186
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 189
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 258
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 261
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 267
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 270
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 317
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 318
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 319
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 471
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 13
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 90
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 95
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 98
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 102
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 105
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 107
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 108
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 126
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 338
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 340
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 342
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 344
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 346
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 348
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 350
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 352
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 466
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 467
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 112
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 21
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 23
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 218
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 337
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 355
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 360
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 361
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 482
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 494
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 498
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 52
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 53
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 58
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 211
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 214
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 259
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 260
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 263
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 266
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 268
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 272
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 274
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 349
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 351
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 353
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 354
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 356
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 357
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 358
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 359
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 362
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 363
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 364
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 366
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 367
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 368
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 370
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 371
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 372
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 373
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 374
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 375
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 45
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 48
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 49
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 56
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 59
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 63
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 381
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 386
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 403
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 432
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 434
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 436
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 438
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 441
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 446
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 447
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 493
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 3
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 83
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 164
#   rowcount = cursor.executemany(statement, parameters)
# ...
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 475
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 476
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 76
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 154
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 18
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 20
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 275
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 284
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 285
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 286
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 150
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 152
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 153
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 156
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 158
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 160
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 161
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 162
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 171
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 184
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 185
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 188
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 191
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 193
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 213
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 215
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 216
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 219
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 94
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 99
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 427
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 291
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 311
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 240
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 287
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 288
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 61
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 80
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 244
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 245
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 448
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 305
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 306
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 307
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 242
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 276
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 265
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 461
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 289
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 304
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 412
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 414
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 454
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 456
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 463
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 468
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 492
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 496
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 401
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 450
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 449
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 452
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 282
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 445
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 310
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 315
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 320
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 292
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'KECAMATAN' at row 294
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'MERK' at row 109
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'MERK' at row 225
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'MERK' at row 256
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'MERK' at row 276
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'MERK' at row 277
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'MERK' at row 279
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'MERK' at row 281
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'MERK' at row 295
#   rowcount = cursor.executemany(statement, parameters)

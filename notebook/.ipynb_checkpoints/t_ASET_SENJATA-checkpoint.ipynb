# %%
import arrow
import pandas as pd
from datetime import datetime
import numpy as np

def convert_todate(df, column_name):
    data_series = []
    len_data = len(df[column_name])
    for idx in range(len_data):
        data = df[column_name].iloc[idx]
        try:
            at = arrow.get(data)
            date = at.date()
            data = date
        except: # jika NAN or NAT
            data = "0000-00-00"

        data_series.append(data)

    df[column_name] = data_series
    return df

# %%
df = pd.read_csv("../data/ASET_SENJATA.csv", sep='|', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    KODE_KL               NAMA_KL  KODE_KPKNL        NAMA_KPKNL  \
# 0       60  KEPOLISIAN NEGARA RI      7104.0  KPKNL JAKARTA IV
# 1       60  KEPOLISIAN NEGARA RI      7104.0  KPKNL JAKARTA IV
# 2       60  KEPOLISIAN NEGARA RI      7104.0  KPKNL JAKARTA IV
# 3       60  KEPOLISIAN NEGARA RI      3103.0   KPKNL PEKANBARU
# 4       60  KEPOLISIAN NEGARA RI      7104.0  KPKNL JAKARTA IV
#
#             KODE_SATKER                              NAMA_SATKER  \
# 0  060010100642012000KD  DIREKTORAT LALU LINTAS POLDA METRO JAYA
# 1  060010100642012000KD  DIREKTORAT LALU LINTAS POLDA METRO JAYA
# 2  060010100642012000KD  DIREKTORAT LALU LINTAS POLDA METRO JAYA
# 3  060010900679401000KD                 DIT PAM OBVIT POLDA RIAU
# 4  060010100642012000KD  DIREKTORAT LALU LINTAS POLDA METRO JAYA
#
#         KODE_SUB_SATKER                          NAMA_SUB_SATKER     KELOMPOK  \
# 0  060010100642012000KD  DIREKTORAT LALU LINTAS POLDA METRO JAYA  SENJATA API
# 1  060010100642012000KD  DIREKTORAT LALU LINTAS POLDA METRO JAYA  SENJATA API
# 2  060010100642012000KD  DIREKTORAT LALU LINTAS POLDA METRO JAYA  SENJATA API
# 3  060010900679401000KD                 DIT PAM OBVIT POLDA RIAU  SENJATA API
# 4  060010100642012000KD  DIREKTORAT LALU LINTAS POLDA METRO JAYA  SENJATA API
#
#       SUB_KELOMPOK  ...  TEMPAT_LAHIR_PEMAKAI TGL_LAHIR_PEMAKAI  GOL_PEMAKAI  \
# 0  SENJATA GENGGAM  ...                   NaN               NaN          NaN
# 1  SENJATA GENGGAM  ...                   NaN               NaN          NaN
# 2  SENJATA GENGGAM  ...                   NaN               NaN          NaN
# 3  SENJATA GENGGAM  ...                   NaN               NaN          NaN
# 4  SENJATA GENGGAM  ...                   NaN               NaN          NaN
#
#   JAB_PEMAKAI JAB_FUNG_PEMAKAI TMT_JAB_PEMAKAI TGL_PENSIUN_PEMAKAI  \
# 0         NaN              NaN             NaN                 NaN
# 1         NaN              NaN             NaN                 NaN
# 2         NaN              NaN             NaN                 NaN
# 3         NaN              NaN             NaN                 NaN
# 4         NaN              NaN             NaN                 NaN
#
#    STATUS_SBSN  STATUS_IDLE   TGL_TARIK
# 0          NaN          NaN  20200225.0
# 1          NaN          NaN  20200225.0
# 2          NaN          NaN  20200225.0
# 3          NaN          NaN  20200225.0
# 4          NaN          NaN  20200225.0
#
# [5 rows x 69 columns]

# %%
df.columns
# Out:
# Index(['KODE_KL', 'NAMA_KL', 'KODE_KPKNL', 'NAMA_KPKNL', 'KODE_SATKER',
#        'NAMA_SATKER', 'KODE_SUB_SATKER', 'NAMA_SUB_SATKER', 'KELOMPOK',
#        'SUB_KELOMPOK', 'KODE_BARANG', 'NAMA_BARANG', 'NUP',
#        'TANGGAL_PEROLEHAN', 'TGL_BUKU', 'TGL_REKAM', 'TGL_REKAM_PERTAMA',
#        'NILAI_PEROLEHAN_PERTAMA', 'NILAI_MUTASI', 'NILAI_PEROLEHAN',
#        'NILAI_PENYUSUTAN', 'NILAI_BUKU', 'KONDISI', 'MERK', 'KUANTITAS',
#        'NO_DANA', 'TGL_DANA', 'DARI', 'ASL_PERLH', 'TGL_PERLH', 'NO_PSP',
#        'TGL_PSP', 'JUMLAH_KIB', 'JUMLAH_FOTO', 'STATUS_PENGELOLAAN',
#        'STATUS_PENGGUNAAN', 'JENIS_PENGGUNA', 'KD_SATKER_PENGGUNA',
#        'UR_SATKER_PENGGUNA', 'ALAMAT_SATKER_PENGGUNA', 'NAMA', 'KALIBER',
#        'NO_PABRIK', 'TAHUN_BUAT', 'SURAT', 'TGL_SURAT', 'NAMA_PABRIK',
#        'NEGARA_PEMBUAT', 'KODE_RUANG', 'NAMA_RUANG', 'KODE_SATKER_BANGUNAN',
#        'KODE_BARANG_BANGUNAN', 'NUP_BARANG_BANGUNAN', 'KIB_BARANG_BANGUNAN',
#        'NO_SIP', 'TGL_SIP', 'NIP_PEMAKAI', 'NAMA_PEMAKAI', 'NO_KTP_PEMAKAI',
#        'TEMPAT_LAHIR_PEMAKAI', 'TGL_LAHIR_PEMAKAI', 'GOL_PEMAKAI',
#        'JAB_PEMAKAI', 'JAB_FUNG_PEMAKAI', 'TMT_JAB_PEMAKAI',
#        'TGL_PENSIUN_PEMAKAI', 'STATUS_SBSN', 'STATUS_IDLE', 'TGL_TARIK'],
#       dtype='object')

# %%
cname = ['TANGGAL_PEROLEHAN', 'TGL_BUKU', 'TGL_REKAM', 'TGL_REKAM_PERTAMA', 'TGL_DANA', 'TGL_PERLH', 'TGL_PSP', 
        'TGL_SURAT', 'TGL_SIP', 'TGL_LAHIR_PEMAKAI', 'TGL_PENSIUN_PEMAKAI','TGL_TARIK']

# %%
df[cname[9]]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 507210   NaN
# 507211   NaN
# 507212   NaN
# 507213   NaN
# 507214   NaN
# Name: TGL_LAHIR_PEMAKAI, Length: 507215, dtype: float64

# %%
df[cname[0]]
# Out:
# 0         1970-12-31 00:00:00.0000000
# 1         1970-12-31 00:00:00.0000000
# 2         1970-12-31 00:00:00.0000000
# 3         2017-12-20 00:00:00.0000000
# 4         1970-12-31 00:00:00.0000000
#                      ...
# 507210    2006-01-23 00:00:00.0000000
# 507211    2006-01-23 00:00:00.0000000
# 507212    2006-01-23 00:00:00.0000000
# 507213    2006-01-23 00:00:00.0000000
# 507214    2006-01-23 00:00:00.0000000
# Name: TANGGAL_PEROLEHAN, Length: 507215, dtype: object

# %%
df = convert_todate(df, column_name=cname[0])
df[cname[0]]
# Out:
# 0         1970-12-31
# 1         1970-12-31
# 2         1970-12-31
# 3         2017-12-20
# 4         1970-12-31
#              ...
# 507210    2006-01-23
# 507211    2006-01-23
# 507212    2006-01-23
# 507213    2006-01-23
# 507214    2006-01-23
# Name: TANGGAL_PEROLEHAN, Length: 507215, dtype: object

# %%
df[cname[1]]
# Out:
# 0         2007-12-31 00:00:00.0000000
# 1         2007-12-31 00:00:00.0000000
# 2         2007-12-31 00:00:00.0000000
# 3         2018-12-31 00:00:00.0000000
# 4         2007-12-31 00:00:00.0000000
#                      ...
# 507210    2008-12-31 00:00:00.0000000
# 507211    2008-12-31 00:00:00.0000000
# 507212    2008-12-31 00:00:00.0000000
# 507213    2008-12-31 00:00:00.0000000
# 507214    2008-12-31 00:00:00.0000000
# Name: TGL_BUKU, Length: 507215, dtype: object

# %%
df = convert_todate(df, column_name=cname[1])
df[cname[1]]
# Out:
# 0         2007-12-31
# 1         2007-12-31
# 2         2007-12-31
# 3         2018-12-31
# 4         2007-12-31
#              ...
# 507210    2008-12-31
# 507211    2008-12-31
# 507212    2008-12-31
# 507213    2008-12-31
# 507214    2008-12-31
# Name: TGL_BUKU, Length: 507215, dtype: object

# %%
df[cname[2]]
# Out:
# 0         2007-12-31 00:00:00.0000000
# 1         2007-12-31 00:00:00.0000000
# 2         2007-12-31 00:00:00.0000000
# 3         2018-12-31 00:00:00.0000000
# 4         2007-12-31 00:00:00.0000000
#                      ...
# 507210    2008-12-31 00:00:00.0000000
# 507211    2008-12-31 00:00:00.0000000
# 507212    2008-12-31 00:00:00.0000000
# 507213    2008-12-31 00:00:00.0000000
# 507214    2008-12-31 00:00:00.0000000
# Name: TGL_REKAM, Length: 507215, dtype: object

# %%
df = convert_todate(df, column_name=cname[2])
df[cname[2]]
# Out:
# 0         2007-12-31
# 1         2007-12-31
# 2         2007-12-31
# 3         2018-12-31
# 4         2007-12-31
#              ...
# 507210    2008-12-31
# 507211    2008-12-31
# 507212    2008-12-31
# 507213    2008-12-31
# 507214    2008-12-31
# Name: TGL_REKAM, Length: 507215, dtype: object

# %%
df[cname[3]]
# Out:
# 0         2007-12-31 00:00:00.0000000
# 1         2007-12-31 00:00:00.0000000
# 2         2007-12-31 00:00:00.0000000
# 3         2018-12-31 00:00:00.0000000
# 4         2007-12-31 00:00:00.0000000
#                      ...
# 507210    2008-12-31 00:00:00.0000000
# 507211    2008-12-31 00:00:00.0000000
# 507212    2008-12-31 00:00:00.0000000
# 507213    2008-12-31 00:00:00.0000000
# 507214    2008-12-31 00:00:00.0000000
# Name: TGL_REKAM_PERTAMA, Length: 507215, dtype: object

# %%
df = convert_todate(df, column_name=cname[3])
df[cname[3]]
# Out:
# 0         2007-12-31
# 1         2007-12-31
# 2         2007-12-31
# 3         2018-12-31
# 4         2007-12-31
#              ...
# 507210    2008-12-31
# 507211    2008-12-31
# 507212    2008-12-31
# 507213    2008-12-31
# 507214    2008-12-31
# Name: TGL_REKAM_PERTAMA, Length: 507215, dtype: object

# %%
df[cname[4]]= df[cname[4]].apply(str)

# %%
df = convert_todate(df, column_name=cname[4])
df[cname[4]]
# Out:
# 0         0000-00-00
# 1         0000-00-00
# 2         0000-00-00
# 3         0000-00-00
# 4         0000-00-00
#              ...
# 507210    0000-00-00
# 507211    0000-00-00
# 507212    0000-00-00
# 507213    0000-00-00
# 507214    0000-00-00
# Name: TGL_DANA, Length: 507215, dtype: object

# %%
df[cname[5]]
# Out:
# 0         1970-12-31 00:00:00.0000000
# 1         1970-12-31 00:00:00.0000000
# 2         1970-12-31 00:00:00.0000000
# 3         2017-12-20 00:00:00.0000000
# 4         1970-12-31 00:00:00.0000000
#                      ...
# 507210    2006-01-23 00:00:00.0000000
# 507211    2006-01-23 00:00:00.0000000
# 507212    2006-01-23 00:00:00.0000000
# 507213    2006-01-23 00:00:00.0000000
# 507214    2006-01-23 00:00:00.0000000
# Name: TGL_PERLH, Length: 507215, dtype: object

# %%
df = convert_todate(df, column_name=cname[5])
df[cname[5]]
# Out:
# 0         1970-12-31
# 1         1970-12-31
# 2         1970-12-31
# 3         2017-12-20
# 4         1970-12-31
#              ...
# 507210    2006-01-23
# 507211    2006-01-23
# 507212    2006-01-23
# 507213    2006-01-23
# 507214    2006-01-23
# Name: TGL_PERLH, Length: 507215, dtype: object

# %%
df[cname[6]] = df[cname[6]].apply(str)

# %%
df = convert_todate(df, column_name=cname[6])
df[cname[6]]
# Out:
# 0         0000-00-00
# 1         0000-00-00
# 2         0000-00-00
# 3         0000-00-00
# 4         0000-00-00
#              ...
# 507210    0000-00-00
# 507211    0000-00-00
# 507212    0000-00-00
# 507213    0000-00-00
# 507214    0000-00-00
# Name: TGL_PSP, Length: 507215, dtype: object

# %%
df[cname[7]] =df[cname[7]].apply(str)

# %%
df = convert_todate(df, column_name=cname[7])
df[cname[7]]
# Out:
# 0         0000-00-00
# 1         0000-00-00
# 2         0000-00-00
# 3         0000-00-00
# 4         0000-00-00
#              ...
# 507210    0000-00-00
# 507211    0000-00-00
# 507212    0000-00-00
# 507213    0000-00-00
# 507214    0000-00-00
# Name: TGL_SURAT, Length: 507215, dtype: object

# %%
df[cname[8]] = df[cname[8]].apply(str)

# %%
df = convert_todate(df, column_name=cname[8])
df[cname[8]]
# Out:
# 0         0000-00-00
# 1         0000-00-00
# 2         0000-00-00
# 3         0000-00-00
# 4         0000-00-00
#              ...
# 507210    0000-00-00
# 507211    0000-00-00
# 507212    0000-00-00
# 507213    0000-00-00
# 507214    0000-00-00
# Name: TGL_SIP, Length: 507215, dtype: object

# %%
df[cname[9]] = df[cname[9]].apply(str)
df[cname[9]]
# Out:
# 0         nan
# 1         nan
# 2         nan
# 3         nan
# 4         nan
#          ...
# 507210    nan
# 507211    nan
# 507212    nan
# 507213    nan
# 507214    nan
# Name: TGL_LAHIR_PEMAKAI, Length: 507215, dtype: object

# %%
df = convert_todate(df, column_name=cname[9])
df[cname[9]]
# Out:
# 0         0000-00-00
# 1         0000-00-00
# 2         0000-00-00
# 3         0000-00-00
# 4         0000-00-00
#              ...
# 507210    0000-00-00
# 507211    0000-00-00
# 507212    0000-00-00
# 507213    0000-00-00
# 507214    0000-00-00
# Name: TGL_LAHIR_PEMAKAI, Length: 507215, dtype: object

# %%
df[cname[10]] = df[cname[10]].apply(str)

# %%
df = convert_todate(df, column_name=cname[10])
df[cname[10]]
# Out:
# 0         0000-00-00
# 1         0000-00-00
# 2         0000-00-00
# 3         0000-00-00
# 4         0000-00-00
#              ...
# 507210    0000-00-00
# 507211    0000-00-00
# 507212    0000-00-00
# 507213    0000-00-00
# 507214    0000-00-00
# Name: TGL_PENSIUN_PEMAKAI, Length: 507215, dtype: object

# %%
df['TGL_TARIK'] = df['TGL_TARIK'].fillna(0)
df['TGL_TARIK']
# Out:
# 0         20200225.0
# 1         20200225.0
# 2         20200225.0
# 3         20200225.0
# 4         20200225.0
#              ...
# 507210    20200225.0
# 507211    20200225.0
# 507212    20200225.0
# 507213    20200225.0
# 507214    20200225.0
# Name: TGL_TARIK, Length: 507215, dtype: float64

# %%
# df['TGL_TARIK'] = df['TGL_TARIK'].apply(np.int64)
# df['TGL_TARIK']

# %%
data = df
column_name = 'TGL_TARIK'

len_data = len(df)
# len_data = 10
data_series = []
for idx in range(len_data):
    len_data = len(df[column_name])
    data = df[column_name].iloc[idx]
    data = str(data)
    
    year = data[0:4]
    month = data[4:6]
    day = data[6:8]
    str_date = f'{year}-{month}-{day}'
#     print(str_date)

    try:
        at = arrow.get(str_date)
        date = at.date()
    except:
        str_date = f'0000-00-00'
#         at = arrow.get(str_date)
#         date = at.date()
        date = str_date
#         print(date)
#     print(date)

    data_series.append(date)

df[column_name] = data_series
df[column_name]
# return df
# Out:
# 0         2020-02-25
# 1         2020-02-25
# 2         2020-02-25
# 3         2020-02-25
# 4         2020-02-25
#              ...
# 507210    2020-02-25
# 507211    2020-02-25
# 507212    2020-02-25
# 507213    2020-02-25
# 507214    2020-02-25
# Name: TGL_TARIK, Length: 507215, dtype: object

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql://root:191618@localhost/db_logpolri')

# %%
df.to_sql('t_ASET_SENJATA', con=engine, if_exists='append', chunksize=500, index=False)
# Out:
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 34
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 130
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 226
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 322
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 418
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 14
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 110
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 206
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 302
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 398
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 494
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 90
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 186
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 282
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 378
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 474
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 70
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 166
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 262
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 358
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 454
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 50
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 146
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 242
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 338
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 434
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 30
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 126
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 222
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 318
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 414
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 10
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 106
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 202
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 298
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 394
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 490
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 86
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 182
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 278
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 374
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 470
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 66
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 162
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 355
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 451
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 47
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 143
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 239
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 335
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 431
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 27
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 123
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 219
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 315
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 411
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 7
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 103
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 199
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 295
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 391
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 487
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 83
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 179
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 275
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 371
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 392
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 488
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 84
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 180
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 276
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 372
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 468
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 64
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 160
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 256
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 352
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 448
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 44
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 140
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 236
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 332
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 428
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 24
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 120
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 216
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 312
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 408
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 4
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 100
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 196
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 292
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 388
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 484
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 80
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 176
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 272
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 368
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 464
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 60
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 156
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 252
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 348
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 444
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 40
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 136
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 232
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 328
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 424
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 20
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 116
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 420
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 16
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 112
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 208
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 212
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 304
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 308
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 400
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 404
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 496
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 500
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 92
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 96
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 188
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 192
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 284
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 288
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 380
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 384
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 476
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 72
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 48
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 71
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 167
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 263
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 359
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 455
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 51
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 147
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 243
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 339
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 435
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 31
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 127
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 161
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 257
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 353
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 449
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 45
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 141
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 237
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 333
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 429
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 25
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 121
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 217
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 313
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 409
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 5
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 101
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 197
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 293
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 389
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 485
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 81
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 173
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 177
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 269
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 273
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 365
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 369
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 461
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 465
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 57
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 61
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 153
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 157
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 249
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 253
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 345
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 349
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 441
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 445
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 37
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 41
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 133
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 137
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 229
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 233
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 325
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 329
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 421
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 425
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 17
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 21
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 113
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 117
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 209
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 213
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 305
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 309
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 401
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 405
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 497
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 1
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 93
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 97
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 189
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 193
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 285
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 289
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 381
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 385
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 477
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 481
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 73
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 77
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 169
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 265
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 361
#   rowcount = cursor.executemany(statement, parameters)
# ...
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 102
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 346
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 442
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 38
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 134
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 230
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 326
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 422
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 18
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 114
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 210
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 306
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 402
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 498
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 94
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 190
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 286
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 382
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 478
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 74
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 170
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 266
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 362
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 458
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 54
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 150
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 246
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 342
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 438
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 223
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 319
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 415
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 11
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 107
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 203
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 299
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 395
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 491
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 87
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 183
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 279
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 375
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 471
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 67
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 163
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 259
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 467
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 63
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 159
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 255
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 234
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 480
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 76
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 172
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 268
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 364
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 460
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 56
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 152
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 248
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 344
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 440
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 36
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 132
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 228
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 324
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 419
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 15
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 168
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 264
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 360
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 456
#   rowcount = cursor.executemany(statement, parameters)
# /opt/anaconda3/envs/work/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:148: Warning: Data truncated for column 'UR_SATKER_PENGGUNA' at row 52
#   rowcount = cursor.executemany(statement, parameters)
